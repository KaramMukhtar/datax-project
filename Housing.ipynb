# %%
import pandas as pd
listings = pd.read_csv('./projectData/HousingPriceData/MedianListingPrice.csv', encoding = "ISO-8859-1")
listings.head()
# Out:
#     RegionName State                             Metro   CountyName  SizeRank  \
# 0     New York    NY       New York-Newark-Jersey City       Queens         1
# 1  Los Angeles    CA    Los Angeles-Long Beach-Anaheim  Los Angeles         2
# 2      Chicago    IL          Chicago-Naperville-Elgin         Cook         3
# 3      Houston    TX  Houston-The Woodlands-Sugar Land       Harris         4
# 4  San Antonio    TX         San Antonio-New Braunfels        Bexar         5
#
#     2010-01   2010-02   2010-03   2010-04   2010-05    ...      2017-12  \
# 0  459000.0  449990.0  429900.0  430000.0  449000.0    ...     850000.0
# 1  434900.0  419000.0  429000.0  429000.0  429000.0    ...     749999.0
# 2  269800.0  274500.0  272500.0  272138.0  269000.0    ...     285000.0
# 3       NaN       NaN       NaN       NaN       NaN    ...     324999.0
# 4  145000.0  147000.0  149000.0  149900.0  150944.0    ...     233765.5
#
# ...
